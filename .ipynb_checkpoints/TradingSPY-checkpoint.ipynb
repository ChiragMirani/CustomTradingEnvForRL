# %% [markdown]
# # Reinforcement Learning Trading Agent to trade S&P 500 ETF
# ## What is the point of this code?
# ### This code uses PPO algorithm from OpenAI's stable baselines to train agent to buy or sell S&P 500 ETF (SPY) on a daily basis.  We train the agent using five years worth of the past data and test it on the subsequent 1-month (most recent period).
# ## Results:
# ###  We found that the reinforcement agent outperforms buy/hold by 1% or 12% annualized for that test month.  This is just an example.  The results are not robust.  One can learn from this code and add/remove features.  Try different training/test periods and/or different algorithms.

# %%
# some useful libraries to install
#!pip install tensorflow-gpu==1.15.0 tensorflow==1.15.0 stable-baselines gym-anytrading gym
#!pip install quantstats
#!pip install finta
#!pip install yfinance
#!pip install yahoofinancials

# %% [markdown]
# # The most important libraries in the code below are
#
# 1. gym_anytrading.  This library has a custom stock trading environment that extends OpenAI gym. This allows us our agent to view the trading environment.  This environment can easily be extended for our purposes.  I can see two usecases for extension: one is adding features (which we do here) and two is ability to lever up (add more than) and buy and sell more than one contract of SPY.

# %%
# Open AI gym and stablebaselines..

import gym
import gym_anytrading
import finta as TA #technical indicators library imported..
from gym_anytrading.envs import StocksEnv
import yfinance as yf


# Stable baselines - rl stuff
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import A2C
from stable_baselines3 import PPO

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import quantstats as qs

# %% [markdown]
# # Pull SPY data from yfinance api..

# %%
#read spy data
df = yf.download('SPY', start='2017-01-01', end='2022-02-11', progress=False)
df.drop("Close", axis=1, inplace=True)
df.rename(columns = {'Adj Close':'Close'}, inplace = True)
df.head()
# Out:
#                   Open        High         Low       Close    Volume
# Date
# 2017-01-03  225.039993  225.830002  223.880005  206.147522  91366500
# 2017-01-04  225.619995  226.750000  225.610001  207.373947  78744400
# 2017-01-05  226.270004  226.580002  225.479996  207.209152  78379000
# 2017-01-06  226.529999  227.750000  225.899994  207.950562  71559900
# 2017-01-09  226.910004  227.070007  226.419998  207.264114  46939700

# %%
df.dtypes
df.shape
# Out:
# (1287, 5)

# %%
#technical indicator creation
df['SMA'] = TA.TA.SMA(df,10)- TA.TA.SMA(df,5)
df['RSI'] = TA.TA.RSI(df)
df['OBV'] = TA.TA.OBV(df)
df['VAMA'] = TA.TA.VAMA(df)
df['HMA'] = TA.TA.HMA(df)
df['MOM'] = TA.TA.MOM(df)
df['ROC'] = TA.TA.ROC(df)
df['ATR'] = TA.TA.ATR(df)
df['ADX'] = TA.TA.ADX(df)
df['UO'] = TA.TA.UO(df)
df["1DayChange"]=df['Close'].diff()
#df["1DIFF2"]=df['1DayChange'].diff()
df["1WeekChange"]=df['Close'].diff(5)
df["1MonthChange"]=df['Close'].diff(21)
#df["vol"] = df['Close'].rolling(5).std()


# lifting prices forward by one day, so lagging feature variables
#df['Close'] = df['Close'].shift(-1)
#df['Open'] = df['Open'].shift(-1)
#df['High'] = df['High'].shift(-1)
#df['Low'] = df['Low'].shift(-1)


df.fillna(0,inplace=True)
df.drop(df.tail(1).index,inplace=True) # drop last n rows

df.tail(5)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2022-02-03  450.950012  452.970001  445.709991  446.600006  118024400
# 2022-02-04  446.350006  452.779999  443.829987  448.700012  118335600
# 2022-02-07  449.510010  450.989990  445.850006  447.260010   84472900
# 2022-02-08  446.730011  451.920013  445.220001  450.940002   81012000
# 2022-02-09  455.220001  457.880005  455.010010  457.540009   92589900
#
#                  SMA        RSI           OBV        VAMA         HMA  \
# Date
# 2022-02-03 -7.185004  44.302038  3.656842e+09  442.204710  444.912143
# 2022-02-04 -7.463004  46.115639  3.775178e+09  444.247159  448.455081
# 2022-02-07 -6.191003  45.032813  3.690705e+09  446.502079  450.639911
# 2022-02-08 -4.142001  48.369284  3.771717e+09  449.153655  452.082151
# 2022-02-09 -1.764001  53.787154  3.864307e+09  451.440978  453.729180
#
#                   MOM       ROC        ATR        ADX         UO  1DayChange  \
# Date
# 2022-02-03  -0.149994 -2.166528  11.062855  31.274523  53.023726  -10.750000
# 2022-02-04  10.720001 -0.675149  11.331427  31.392660  55.658053    2.100006
# 2022-02-07   7.420013  0.114160  11.026426  31.502359  59.616165   -1.440002
# 2022-02-08  16.470001  2.959037  10.922856  31.484463  57.363122    3.679993
# 2022-02-09  24.160004  4.024193  10.401428  30.682629  57.740119    6.600006
#
#             1WeekChange  1MonthChange
# Date
# 2022-02-03    15.360016    -30.949982
# 2022-02-04     6.750000    -19.679993
# 2022-02-07    -2.649994    -20.679993
# 2022-02-08    -2.010010    -15.149994
# 2022-02-09     0.190002     -7.970001

# %%
window_size = 1
start_index = window_size
end_index = 1265
env = gym.make('stocks-v0', df=df, frame_bound=(start_index,end_index), window_size=window_size)

def add_signals(env):
    #calculate the starting index, getting our first frame value, start at 0
    #frame bound is equal to one.  Env.Window_size is also equal to one.  Thus, we are starting at zero
    start = env.frame_bound[0]-env.window_size
    
    #getting the end of our frame, which in this case is 200
    end = env.frame_bound[1]
    #get prices from our start to our end
    prices = env.df.loc[:,'Close'].to_numpy()[start:end]
    #signal_features = env.df.loc[:,['SMA', 'RSI','OBV','VAMA','HMA','MOM','ROC','ATR','ADX','UO','1DayChange','1WeekChange','1MonthChange']].to_numpy()[start:end]
    signal_features = env.df.loc[:,['Close','1DayChange','1WeekChange','1MonthChange','ATR']].to_numpy()[start:end]
    

    return prices, signal_features

class MyCustomEnv(StocksEnv):
    _process_data = add_signals


env = MyCustomEnv(df=df, window_size =window_size, frame_bound=(start_index,end_index))

# %% [markdown]
# # 2. Build Environment

# %%
env.action_space
# Out:
# Discrete(2)

# %%
state = env.reset()
while True: 
    action = env.action_space.sample()
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
# Out:
# info {'total_reward': 89.55659484863281, 'total_profit': 0.011393573589703746, 'position': 1}

# %% [markdown]
# # 3. Build Environment and Train

# %%
window_size = 1
start_index = window_size
end_index = 1265

env_maker = lambda: env
env = DummyVecEnv([env_maker])

# %%
model = PPO('MlpPolicy', env, verbose=1, seed=100) 
#model = A2C('MlpPolicy', env, verbose=1, seed=100)
model.learn(total_timesteps=50000)
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 687  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 497         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016788648 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | -0.00226    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00342    |
# |    value_loss           | 39.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011585465 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.659      |
# |    explained_variance   | 0.00982     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0016     |
# |    value_loss           | 45.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 409         |
# |    iterations           | 4           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006600075 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.603      |
# |    explained_variance   | 0.0153      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0017     |
# |    value_loss           | 65.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 398          |
# |    iterations           | 5            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0045087296 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.568       |
# |    explained_variance   | 0.0447       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.7         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 59           |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 396           |
# |    iterations           | 6             |
# |    time_elapsed         | 30            |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | 0.00018890377 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.551        |
# |    explained_variance   | 0.0642        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 60.1          |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00123      |
# |    value_loss           | 85.4          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 390          |
# |    iterations           | 7            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0021353487 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.088        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.9         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 63.4         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 389          |
# |    iterations           | 8            |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032461719 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.545       |
# |    explained_variance   | 0.186        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11           |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 42.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 388          |
# |    iterations           | 9            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0051609874 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.7         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00375     |
# |    value_loss           | 75.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 387           |
# |    iterations           | 10            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00090656825 |
# |    clip_fraction        | 4.88e-05      |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.591        |
# |    explained_variance   | 0.164         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 13.1          |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -0.000173     |
# |    value_loss           | 46.3          |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 11          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006863856 |
# |    clip_fraction        | 0.00986     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.556      |
# |    explained_variance   | 0.202       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00148    |
# |    value_loss           | 52.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 387          |
# |    iterations           | 12           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0036019576 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.565       |
# |    explained_variance   | 0.187        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00342     |
# |    value_loss           | 63.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 13          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.005771467 |
# |    clip_fraction        | 0.00508     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.531      |
# |    explained_variance   | 0.284       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 53.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 386          |
# |    iterations           | 14           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0014491137 |
# |    clip_fraction        | 9.77e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.487       |
# |    explained_variance   | 0.195        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.5         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000989    |
# |    value_loss           | 72.8         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 385          |
# |    iterations           | 15           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0015827494 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.518       |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28           |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0011      |
# |    value_loss           | 94.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 384         |
# |    iterations           | 16          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003175083 |
# |    clip_fraction        | 0.000928    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.495      |
# |    explained_variance   | 0.237       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000404   |
# |    value_loss           | 55.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 383          |
# |    iterations           | 17           |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0025915094 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.454       |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20           |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 71.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 18           |
# |    time_elapsed         | 96           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0006429193 |
# |    clip_fraction        | 0.0146       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.466       |
# |    explained_variance   | 0.366        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.3         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00259     |
# |    value_loss           | 41.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 19           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0021551652 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.484       |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 26.6         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00285     |
# |    value_loss           | 84.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 381         |
# |    iterations           | 20          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002263185 |
# |    clip_fraction        | 0.017       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.468      |
# |    explained_variance   | 0.444       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.4        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 46.2        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 382          |
# |    iterations           | 21           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0015714683 |
# |    clip_fraction        | 0.0221       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.491       |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.1         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00216     |
# |    value_loss           | 47.2         |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 381           |
# |    iterations           | 22            |
# |    time_elapsed         | 118           |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00087856635 |
# |    clip_fraction        | 0.0109        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.48         |
# |    explained_variance   | 0.377         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 21.1          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000983     |
# |    value_loss           | 67.9          |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 379          |
# |    iterations           | 23           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0010878041 |
# |    clip_fraction        | 0.0178       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.486       |
# |    explained_variance   | 0.397        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 30.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 61.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 24           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0012831327 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.5         |
# |    explained_variance   | 0.483        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.8         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 44.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 380          |
# |    iterations           | 25           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0012248397 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.503       |
# |    explained_variance   | 0.363        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00257     |
# |    value_loss           | 84.6         |
# ------------------------------------------

# %% [markdown]
# # 4. Evaluation

# %%
window_size = 1
start_index = 1265+window_size
end_index = 1286
#start_index = window_size
#end_index = 1265

env = MyCustomEnv(df=df, window_size=window_size, frame_bound=(start_index, end_index))
#env = gym.make('stocks-v0', df=df, frame_bound=(start_index,end_index), window_size=window_size)

obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    #print(obs)
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    #print(action)
    print(obs)
    print(info)
    if done:
        print("info", info)
        break
# Out:
# [[471.01998901   1.26998901   2.63998413   6.08340454   5.12214443]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[464.52999878  -6.48999023  -3.41000366   2.79220581   5.47500174]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[ 4.64720001e+02  1.90002441e-01 -1.36999512e+00 -4.23245239e+00
#    5.36643110e+00]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[456.48999023  -8.23001099  -9.02001953  -8.32699585   5.84214565]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[451.75        -4.73999023 -18.          -8.11999512   6.23571777]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[446.75        -5.         -24.26998901  -8.23001099   7.01500375]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[437.98001099  -8.76998901 -26.54998779 -25.07998657   7.58071899]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[439.83999634   1.85998535 -24.88000488 -27.8500061    8.69643293]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[434.47000122  -5.36999512 -22.01998901 -36.13000488   9.28857422]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[433.38000488  -1.08999634 -18.36999512 -43.88000488   9.68000357]]
# {'total_reward': 0.0, 'total_profit': 1.0, 'position': 1}
# [[431.23999023  -2.14001465 -15.51000977 -45.63000488  10.16214425]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 0}
# [[441.95001221  10.71002197   3.97000122 -35.52999878  10.84999956]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[449.91000366   7.95999146  10.07000732 -26.25        10.92000035]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[452.95001221   3.04000854  18.48001099 -22.00997925  10.8407135 ]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[457.3500061    4.3999939   23.97000122 -20.35998535  10.90571158]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[446.6000061  -10.75        15.36001587 -30.94998169  11.06285531]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[448.70001221   2.1000061    6.75       -19.67999268  11.33142744]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[447.26000977  -1.44000244  -2.6499939  -20.67999268  11.02642604]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9371684512701882, 'position': 1}
# [[450.94000244   3.67999268  -2.01000977 -15.1499939   10.92285592]]
# {'total_reward': -22.579986572265625, 'total_profit': 0.9388135770469257, 'position': 1}
# info {'total_reward': -22.579986572265625, 'total_profit': 0.9388135770469257, 'position': 1}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
env.prices
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19116/2881464309.py in <module>
#       1 plt.figure(figsize=(15,6))
#       2 plt.cla()
# ----> 3 env.render_all()
#       4 plt.show()
#       5 env.prices
#
# AttributeError: 'DummyVecEnv' object has no attribute 'render_all'

# %%
qs.extend_pandas()


net_worth = pd.Series(env.history['total_profit'], index=df.index[start_index+1:end_index])
returns = net_worth.pct_change().iloc[1:]

qs.reports.full(returns)
#qs.reports.html(returns, output='a2c_quantstats.html')

# %%
state = env.reset()
while True: 
    action = 1
    n_state, reward, done, info = env.step(action)
    if done: 
        print("info", info)
        break
        
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
